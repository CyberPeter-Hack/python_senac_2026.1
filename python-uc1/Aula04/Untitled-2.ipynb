# %% [markdown]
# # Aula04

# %%
meu_livro = "Python para Iniciantes"
print(meu_livro)
# Out:
# Python para Iniciantes

# %%
nome = str(input('Digite seu nome: '))
anonasc = int(input('Digite o ano que você nasceu: '))
print ('Seu nome é {} e você tem {}anos'.format(nome, 2026-anonasc))
# Out:
# Seu nome é gui e você tem 36anos

# %%
inteiro = 10
ponto_flutuante = 3.14
numero_complexo = 2 +3j

print(type(inteiro))
print(type(ponto_flutuante))
print(type(numero_complexo))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# # Testando as Strings

# %%
nome="Guilherme"

# %%
cep="25680-276"

# %%
logadouro = """Rua Sao Sebastião, 222
Bairro: São Sebastião
Cidade: Petrópolis
Estado: Rio de Janeiro"""

print(logadouro)
# Out:
# Rua Sao Sebastião, 222
# Bairro: São Sebastião
# Cidade: Petrópolis
# Estado: Rio de Janeiro

# %%
n1=5
n2=7
resultado=n1 > n2
resultado2=n1 < n2

print (resultado, resultado2)
# Out:
# False True

# %% [markdown]
# # Listas - Tuplas e Ranges

# %%
tupla=(1,2)
type(tupla)
# Out:
# tuple

# %%
lista=[1,2]
type(lista)
# Out:
# list

# %%
print(lista)
# Out:
# [1, 2]

# %%
print(tupla[1])
# Out:
# 2

# %%
lista[1]=3
print(lista)
# Out:
# [1, 3, 4, 5, 4, 5]

# %%
print(lista)
# Out:
# [1, 3, 4, 5, 4, 5]

# %%
lista=list(range(1,100,5))
print(lista)
# Out:
# [1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81, 86, 91, 96]

# %%
nome = str(input('Digiteseu nome: '))
idade=int(input(f'{nome} digite sua idade: '))

# %%
idade=2026-ano_nasc

# %%
if idade >= 18 :
    print (f'{nome}, você é MAIOR de idade!')
else :
    print (f'{nome}, você é MENOR de idade!')
# Out:
# joese, você é MAIOR de idade!

# %%
if idade >= 18 :
    print (f'{nome}, você é MAIOR de idade!')
elif idade >= 16 :
    print (f'{nome}, você é adolescente!')
else :
    print (f'{nome}, você é MENOR de idade!')
# Out:
# Gui, você é MENOR de idade!
