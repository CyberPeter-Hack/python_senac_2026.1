# %% [markdown]
# ## Aula11

# %%
d1 = {}
d2 = dict()

telefones = {'Alice': '2223-8896',
             'Bruno': '5569-9685',
             'Guilherme': '2225-8998',
             'José': '9956-5687'}
print(telefones)
# Out:
# {'Alice': '2223-8896', 'Bruno': '5569-9685', 'Guilherme': '2225-8998', 'José': '9956-5687'}

# %%
print(telefones['José'])

telefones['Papagaio']='2222-5694'
telefones['Guilherme']='99299-8597'
# Out:
# 9956-5687

# %%
print(telefones['Papagaio'])
# Out:
# 2222-5694

# %%
d3 = dict(nome='Carlos', idade=25)
print(d3)
# Out:
# {'nome': 'Carlos', 'idade': 25}

# %%
chaves = ["nome", "idade", "cidade"]
valor_padrao = "N/A"
usuario = dict.fromkeys(chaves, valor_padrao)

# Resultado: {'nome': 'N/A', 'idade': 'N/A', 'cidade': 'N/A'}

print(usuario)
usuario['nome']='Luis Rodrigo'
usuario['idade']=50
usuario['cidade']='Petrópolis'

print(usuario)
# Out:
# {'nome': 'N/A', 'idade': 'N/A', 'cidade': 'N/A'}
# {'nome': 'Luis Rodrigo', 'idade': 50, 'cidade': 'Petrópolis'}

# %%
usuario['nome']=input('Digite seu nome: ')
usuario['idade']=input('Digite sua idade: ')
usuario['logradouro']=input('Digite seu lougadouro: ')
usuario['cep']=input('Digite seu cep: ')
usuario['cidade']=input('Digite sua cidade: ')
usuario['bairro']=input('Digite seu bairro: ')
usuario['estado']=input('Digite seu estado: ')

for chave, valor in usuario.items():
    print(f'{chave.capitalize():-<20}: {valor.capitalize()}')
# Out:
# Nome----------------: Guilherme blanc
# Idade---------------: 36
# Cidade--------------: Petrópolis
# Logradouro----------: Av. barão do rio branco 3050
# Cep-----------------: 25680-276
# Bairro--------------: Centro
# Estado--------------: Rj

# %%
clientes={}
clientes['13070353703']=usuario
print(clientes)
# Out:
# {'13070353703': {'nome': 'Guilherme Blanc', 'idade': '36', 'cidade': 'Petrópolis', 'logradouro': 'Av. Barão do Rio Branco 3050', 'cep': '25680-276', 'bairro': 'Centro', 'estado': 'Rj'}}
