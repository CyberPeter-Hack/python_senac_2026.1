# %%
minha_lista=[1]
print(minha_lista)
# Out:
# [1]

# %%
minha_lista.append(10)
minha_lista.insert(0,8)

print(minha_lista)
# Out:
# [8, 1, 10, 10]

# %%
len(minha_lista)
# Out:
# 4

# %%
minha_lista.sort()
print(minha_lista)
# Out:
# [1, 8, 10, 10]

# %%
minha_lista.remove(10)
print(minha_lista)
# Out:
# [1, 8, 10]
